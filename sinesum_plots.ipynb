# %%
import sinesum as sin
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## t = 0.01*2π n = 1 T = 2π

# %%
sin.plot(0.01*2*np.pi,1,2*np.pi)

# %%
sin.plot(0.01*2*np.pi,3,2*np.pi)

# %%
sin.plot(0.01*2*np.pi,5,2*np.pi)

# %%
sin.plot(0.01*2*np.pi,10,2*np.pi)

# %%
sin.plot(0.01*2*np.pi,30,2*np.pi)

# %%
sin.plot(0.01*2*np.pi,100,2*np.pi)

# %% [markdown]
# ## Analysis

# %% [markdown]
# As the number of points plotted increases to 10, with a alpha of 0.01, the line is growing at a constant rate. When the number of points plotted is over 10 the graph begins to oscillate at a decreasing rate, which will eventually converge to 1.

# %% [markdown]
# ## t= 0.25*2π n = 1 T= 2π

# %%
sin.plot(0.25*2*np.pi,1,2*np.pi)

# %%
sin.plot(0.25*2*np.pi,3,2*np.pi)

# %%
sin.plot(0.25*2*np.pi,5,2*np.pi)

# %%
sin.plot(0.25*2*np.pi,10,2*np.pi)

# %%
sin.plot(0.25*2*np.pi,30,2*np.pi)

# %%
sin.plot(0.25*2*np.pi,100,2*np.pi)

# %% [markdown]
# ## Analysis
# When Alpha increases to 0.25, the graph looks diffrent then the pervious one.
# As the plotted points increase the graph oscillates and eventully converges to 1, but thses oscillations are much sharper then thr perivious one.

# %% [markdown]
# ## t = 0.49*2π n= 1 T = 2π

# %%
sin.plot(0.49*2*np.pi,1,2*np.pi)

# %%
sin.plot(0.49*2*np.pi,3,2*np.pi)

# %%
sin.plot(0.49*2*np.pi,5,2*np.pi)

# %%
sin.plot(0.49*2*np.pi,10,2*np.pi)

# %%
sin.plot(0.49*2*np.pi,30,2*np.pi)

# %%
sin.plot(0.49*2*np.pi,100,2*np.pi)

# %% [markdown]
# ## Analysis
# As the alpha goes up to 0.49 the graph begins to look very similar to the graph with aplpha 0.01.
# The graph has the same behavior as graph with apha 0.01, in which it oscillates at a deacresing rate and converges to 1.
